# %% [markdown]
# <a href="https://colab.research.google.com/github/SomayaRasoli/-leri-Derin-renme/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os #işletim sistemi (Operating System) modülünü içeri aktarır.
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic #(%%backend) oluştur sağlar.
def backend(line, cell):#Bu fonksiyon iki parametre alır:line: Hücrenin başına yazdığınız argüman (örneğin: %%backend jax yazarsanız, line değeri "jax" olur).

                        #cell: O hücrenin içindeki tüm kodlar.
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %%
#Image classification
#Introduction to ConvNets


import keras
from keras import layers

inputs = keras.Input(shape=(28, 28, 1)) #Anlamı: Modelin $28 \times 28$ piksel boyutunda ve tek kanallı (siyah-beyaz) görselleri kabul edeceğini söyler. Eğer görseller renkli olsaydı, son rakam 3 (RGB) olurdu.
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)#Filtreler (64, 128, 256): Ağ ilerledikçe filtre sayısı artar
x = layers.MaxPooling2D(pool_size=2)(x) #Kernel Size (3): Görüntü üzerinde gezen $3 \times 3$ boyutundaki küçük pencerelerdir.
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)#ReLU: Negatif değerleri sıfırlayarak modelin doğrusal olmayan karmaşık ilişkileri öğrenmesini sağlar.
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x) #Modern Yaklaşım: Eskiden burada tüm veriyi tek bir sütuna dizen Flatten kullanılırdı. GlobalAveragePooling ise her filtrenin ortalamasını alarak veriyi küçültür. Bu, modelin parametre sayısını azaltır ve aşırı öğrenmeyi (overfitting) engeller.
outputs = layers.Dense(10, activation="softmax")(x) #Softmax: 10 farklı sınıf (örneğin 0'dan 9'a kadar rakamlar) için olasılık üretir. Tüm çıktıların toplamı 1 olur; en yüksek olasılığa sahip sınıf, modelin tahminidir.
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)          │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                   │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)      │ (None, 13, 13, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)                 │ (None, 11, 11, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# ...

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 233s 241ms/step - accuracy: 0.9226 - loss: 0.2480
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 212s 226ms/step - accuracy: 0.9775 - loss: 0.0723
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 212s 226ms/step - accuracy: 0.9852 - loss: 0.0468
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 210s 224ms/step - accuracy: 0.9887 - loss: 0.0366
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 206s 220ms/step - accuracy: 0.9913 - loss: 0.0275

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9909 - loss: 0.0264
# Test accuracy: 0.991

# %%
#print(f"Test accuracy: {test_acc:.3f}")
#The convolution operation
#Understanding border effects and padding
#Understanding convolution strides
#The max-pooling operation


inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary(line_length=80)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)                 │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)                 │ (None, 24, 24, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)                 │ (None, 22, 22, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# ...

# %%
#Training a ConvNet from scratch on a small dataset
#The relevance of deep learning for small-data problems
#Downloading the data

import kagglehub

kagglehub.login()

# %%
import os

# Kendi bilgilerini buraya tırnak içine yaz
os.environ['KAGGLE_USERNAME'] = "geedik_proje"
os.environ['KAGGLE_KEY'] = "KGAT_f73674a48e0a8783b440132e6b3e965e"
try:
    # Bu komut her şeyi otomatik halleder
    path = kagglehub.competition_download("dogs-vs-cats")
    print("İŞLEM TAMAM! Veri başarıyla indi:", path)
except Exception as e:
    print("Hala bir sorun var:", e)

print("Kimlik bilgileri başarıyla sisteme kaydedildi!")
# Out:
# Hala bir sorun var: 401 Client Error.
#
# You don't have permission to access resource at URL: https://api.kaggle.com/competitions/dogs-vs-cats
# Please make sure you are authenticated and have accepted the competition rules which can be found at this location: https://api.kaggle.com/competitions/dogs-vs-cats/rules
# Kimlik bilgileri başarıyla sisteme kaydedildi!

# %% [markdown]
# Building your model

# %%
download_path = kagglehub.competition_download("dogs-vs-cats")

# %%
import zipfile

with zipfile.ZipFile(download_path + "/train.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("dogs_vs_cats_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x) #Final Kararı: Burada tek bir nöron vardır.
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)          │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ rescaling (Rescaling)             │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                   │ (None, 178, 178, 32)     │           896 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)      │ (None, 89, 89, 32)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# ...

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %% [markdown]
# Data preprocessing

# %%
import os, shutil

base_dir = "dogs_vs_cats_small/train"
# Hedef klasörleri oluştur
cats_dir = os.path.join(base_dir, "cats")
dogs_dir = os.path.join(base_dir, "dogs")

os.makedirs(cats_dir, exist_ok=True)
os.makedirs(dogs_dir, exist_ok=True)

for filename in os.listdir(base_dir):
    src_path = os.path.join(base_dir, filename)

    # KRİTİK KONTROL: Eğer baktığımız şey bir DOSYA ise (klasör değilse) işlem yap
    if os.path.isfile(src_path):
        if filename.startswith("cat"):
            shutil.move(src_path, os.path.join(cats_dir, filename))
        elif filename.startswith("dog"):
            shutil.move(src_path, os.path.join(dogs_dir, filename))

print("Düzenleme tamamlandı! Artık kedi resimleri 'cats', köpekler 'dogs' klasöründe.")
# Out:
# Düzenleme tamamlandı! Artık kedi resimleri 'cats', köpekler 'dogs' klasöründe.

# %% [markdown]
# Understanding TensorFlow Dataset objects

# %%
import numpy as np
import tensorflow as tf

random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(
    lambda x: tf.reshape(x, (4, 4)), #Gelen her bir veriyi (x) alır ve onu 4x4 boyutunda bir kareye (matrise) dönüştürür.
    num_parallel_calls=8)#Bu işlemi sadece tek bir işlemci çekirdeğiyle değil, 8 farklı koldan aynı anda yapmasını söyler.
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# Fitting the model

# %%
import os
import shutil

train_path = "dogs_vs_cats_small/train"

# 1. Hedef klasör yollarını netleştirelim
cats_dir = os.path.join(train_path, "cats")
dogs_dir = os.path.join(train_path, "dogs")

# Klasörleri oluştur
os.makedirs(cats_dir, exist_ok=True)
os.makedirs(dogs_dir, exist_ok=True)

# 2. Ana klasördeki dosyaları tara ve içine taşı
files = os.listdir(train_path)
for f in files:
    src = os.path.join(train_path, f)

    # Sadece DOSYA ise taşı (klasörleri taşıma ki hata vermesin)
    if os.path.isfile(src):
        if f.startswith("cat"):
            shutil.move(src, os.path.join(cats_dir, f))
        elif f.startswith("dog"):
            shutil.move(src, os.path.join(dogs_dir, f))

# 3. Fazlalık olan 'cat' klasörünü silelim (Keras 3 sınıf sanmasın)
wrong_cat_dir = os.path.join(train_path, "cat")
if os.path.exists(wrong_cat_dir) and os.path.isdir(wrong_cat_dir):
    # Eğer içi boşsa sil, doluysa içindekileri 'cats'e aktarabilirsin
    shutil.rmtree(wrong_cat_dir)

print("Dosyalar başarıyla düzenlendi!")
print("Yeni klasör yapısı:", os.listdir(train_path))
# Out:
# Dosyalar başarıyla düzenlendi!
# Yeni klasör yapısı: ['dogs', 'cats']

# %%
import os
import shutil

# 1. Yolları Tanımlayalım
base_path = "dogs_vs_cats_small/train"
cats_dir = os.path.join(base_path, "cats")
dogs_dir = os.path.join(base_path, "dogs")

# Klasörleri oluştur (zaten varsa bir şey yapmaz)
os.makedirs(cats_dir, exist_ok=True)
os.makedirs(dogs_dir, exist_ok=True)

# 2. Resimlerin nerede olduğunu bulalım ve taşıyalım
# Bu döngü train klasörünün içindeki HER ŞEYE bakar
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.endswith(('.jpg', '.jpeg', '.png')):
            src_path = os.path.join(root, file)

            # Eğer dosya ismi kedi ile başlıyorsa cats klasörüne, değilse dogs'a
            if file.startswith("cat"):
                target_path = os.path.join(cats_dir, file)
            elif file.startswith("dog"):
                target_path = os.path.join(dogs_dir, file)
            else:
                continue

            # Eğer dosya zaten hedefte değilse taşı
            if src_path != target_path:
                shutil.move(src_path, target_path)

print("Taşıma bitti! Şimdi klasörleri kontrol edelim:")
print(f"Kedi sayısı: {len(os.listdir(cats_dir))}")
print(f"Köpek sayısı: {len(os.listdir(dogs_dir))}")
# Out:
# Taşıma bitti! Şimdi klasörleri kontrol edelim:
# Kedi sayısı: 0
# Köpek sayısı: 0

# %% [markdown]
# Data preprocessing

# %%
if 'history' in locals():
    print("Müjde! History değişkeni hafızada mevcut.")
else:
    print("Hata: History hala tanımlanmamış. Lütfen model.fit hücresini çalıştır.")
# Out:
# Hata: History hala tanımlanmamış. Lütfen model.fit hücresini çalıştır.

# %%
import os
import keras
from keras.utils import image_dataset_from_directory

# 1. Klasör yollarını tanımla
# Not: 'dogs_vs_cats_small' klasörünün var olduğundan emin ol
train_dir = "dogs_vs_cats_small/train"
val_dir = "dogs_vs_cats_small/validation"

# 2. Veri setlerini OLUŞTUR (Hata burada çözülecek)
try:
    train_dataset = image_dataset_from_directory(
        train_dir,
        image_size=(180, 180),
        batch_size=32
    )
    validation_dataset = image_dataset_from_directory(
        val_dir,
        image_size=(180, 180),
        batch_size=32
    )
    print("MÜJDE: Veri setleri başarıyla oluşturuldu!")
except Exception as e:
    print("HATA: Hala resimleri bulamıyorum. Klasör yapısını kontrol etmelisin!")
    print(e)

# 3. Eğer yukarıdaki kısım başarılıysa, şimdi eğitimi başlat
if 'train_dataset' in locals():
    callbacks = [
        keras.callbacks.ModelCheckpoint(
            filepath="convnet_from_scratch.keras",
            save_best_only=True,
            monitor="val_loss")
    ]

    history = model.fit(
        train_dataset,
        epochs=10,
        validation_data=validation_dataset,
        callbacks=callbacks
    )
# Out:
# Found 0 files belonging to 2 classes.
# HATA: Hala resimleri bulamıyorum. Klasör yapısını kontrol etmelisin!
# No images found in directory dogs_vs_cats_small/train. Allowed formats: ('.bmp', '.gif', '.jpeg', '.jpg', '.png')

# %% [markdown]
# Using data augmentation

# %%
import os
import shutil

# 1. Yolları belirleyelim
base_train_dir = "dogs_vs_cats_small/train"
cats_target = os.path.join(base_train_dir, "cats")
dogs_target = os.path.join(base_train_dir, "dogs")

os.makedirs(cats_target, exist_ok=True)
os.makedirs(dogs_target, exist_ok=True)

# 2. TÜM sistemi tara ve resimleri bulup taşı
# Bu kod, dogs_vs_cats_small içindeki her alt klasöre bakacaktır
for root, dirs, files in os.walk("dogs_vs_cats_small"):
    # Hedef klasörlerin kendisini taramaya çalışma (sonsuz döngü olmasın)
    if root == cats_target or root == dogs_target:
        continue

    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            src_path = os.path.join(root, file)

            if file.lower().startswith("cat"):
                shutil.move(src_path, os.path.join(cats_target, file))
            elif file.lower().startswith("dog"):
                shutil.move(src_path, os.path.join(dogs_target, file))

print("Taşıma işlemi tamamlandı!")
print(f"Cats klasöründeki resim sayısı: {len(os.listdir(cats_target))}")
print(f"Dogs klasöründeki resim sayısı: {len(os.listdir(dogs_target))}")
# Out:
# Taşıma işlemi tamamlandı!
# Cats klasöründeki resim sayısı: 0
# Dogs klasöründeki resim sayısı: 0

# %%
import os
import shutil

# 1. Yolları belirleyelim
base_train_dir = "dogs_vs_cats_small/train"
cats_target = os.path.join(base_train_dir, "cats")
dogs_target = os.path.join(base_train_dir, "dogs")

os.makedirs(cats_target, exist_ok=True)
os.makedirs(dogs_target, exist_ok=True)

# 2. TÜM sistemi tara ve resimleri bulup taşı
# Bu kod, dogs_vs_cats_small içindeki her alt klasöre bakacaktır
for root, dirs, files in os.walk("dogs_vs_cats_small"):
    # Hedef klasörlerin kendisini taramaya çalışma (sonsuz döngü olmasın)
    if root == cats_target or root == dogs_target:
        continue

    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            src_path = os.path.join(root, file)

            if file.lower().startswith("cat"):
                shutil.move(src_path, os.path.join(cats_target, file))
            elif file.lower().startswith("dog"):
                shutil.move(src_path, os.path.join(dogs_target, file))

print("Taşıma işlemi tamamlandı!")
print(f"Cats klasöründeki resim sayısı: {len(os.listdir(cats_target))}")
print(f"Dogs klasöründeki resim sayısı: {len(os.listdir(dogs_target))}")
# Out:
# Taşıma işlemi tamamlandı!
# Cats klasöründeki resim sayısı: 0
# Dogs klasöründeki resim sayısı: 0

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
]

def data_augmentation(images, targets):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images, targets

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
import os

# Tüm dizini tara ve içinde .jpg olan klasörleri listele
print("Sistemdeki tüm klasörler taranıyor...")
for root, dirs, files in os.walk("/content"): # Google Colab için /content, bilgisayar için .
    jpg_files = [f for f in files if f.lower().endswith(".jpg")]
    if len(jpg_files) > 0:
        print(f"BULDUM! Klasör: {root} | Resim Sayısı: {len(jpg_files)}")
# Out:
# Sistemdeki tüm klasörler taranıyor...

# %%
# !find dogs_vs_cats_small -name "*.jpg" | wc -l
# Out:
# 0

# %%
# !unzip -q train.zip -d dogs_vs_cats_small/
# Out:
# unzip:  cannot find or open train.zip, train.zip.zip or train.zip.ZIP.

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset("xception_41_imagenet")
# Out:
# ...
# 100%|██████████| 1.79k/1.79k [00:00<00:00, 3.81MB/s]
# ...
# 100%|██████████| 79.9M/79.9M [00:00<00:00, 118MB/s]

# %%
preprocessor = keras_hub.layers.ImageConverter.from_preset(
    "xception_41_imagenet",
    image_size=(180, 180),
)

# %%
import os
# Klasörlerin var olduğundan emin olalım
os.makedirs("dogs_vs_cats_small/train/cats", exist_ok=True)
os.makedirs("dogs_vs_cats_small/train/dogs", exist_ok=True)
os.makedirs("dogs_vs_cats_small/validation/cats", exist_ok=True)
os.makedirs("dogs_vs_cats_small/validation/dogs", exist_ok=True)
os.makedirs("dogs_vs_cats_small/test/cats", exist_ok=True)
os.makedirs("dogs_vs_cats_small/test/dogs", exist_ok=True)

print("Klasörler hazır. Şimdi resimleri içine yüklemiş olman gerekiyor.")
# Out:
# Klasörler hazır. Şimdi resimleri içine yüklemiş olman gerekiyor.

# %%
from keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    "dogs_vs_cats_small/train",
    image_size=(180, 180),
    batch_size=32
)
# Aynı işlemi validation ve test için de yapmalısın.
# Out:
# Found 0 files belonging to 2 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_456/2841415642.py in <cell line: 0>()
#       1 from keras.utils import image_dataset_from_directory
#       2
# ----> 3 train_dataset = image_dataset_from_directory(
#       4     "dogs_vs_cats_small/train",
#       5     image_size=(180, 180),
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     370         )
#     371         if not image_paths:
# --> 372             raise ValueError(
#     373                 f"No images found in directory {directory}. "
# ...
